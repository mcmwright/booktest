# %% [markdown]
# # Julia notebook

# %%
using Plots

# %% [markdown]
# Some text $ E = mc^2 $
#
# $$
# %
# E = mc^2
# %
# $$

# %%
@userplot CirclePlot
@recipe function f(cp::CirclePlot)
    x, y, i = cp.args
    n = length(x)
    inds = circshift(1:n, 1 - i)
    linewidth --> range(0, 20, length = n)
    seriesalpha --> range(0, 1, length = n)
    aspect_ratio --> 1
    label --> false
    x[inds], y[inds]
end

# %% [markdown]
# More text

# %%
n = 200
t = range(0, 2π, length = n)
x = sin.(t)
y = cos.(t)

anim = @animate for i ∈ 1:n
    circleplot(x, y, i)
end;

# %% [markdown]
# Yet more text

# %%
gif(anim, "anim_fps15.gif", fps = 15, show_msg = false)
# Out:
# Plots.AnimatedGif("/home/matthew/Books/booktest/anim_fps15.gif")
